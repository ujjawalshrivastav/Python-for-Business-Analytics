# %%
def is_even(num): 
    """
    This function returns if a given number is odd or even 
    input = any valid integer
    output = odd/even
    created on = 07-Jan-2026
    """
    if type(num) == int:
        if num % 3 ==0: 
            return'even'
        else: 
            return ' odd'
    else: 
        return"not num"

# %%
for i in range(1, 11): 
    x = is_even(i)
    print(x)
# Out:
#  odd
#  odd
# even
#  odd
#  odd
# even
#  odd
#  odd
# even
#  odd

# %%
is_even('Hellow')
# Out:
# 'not num'

# %%
#Default argument 
def power(a=1, b=1): 
    """This function returns squer of number """
    return a**b

# %%
power()
# Out:
# 1

# %%
power(5)
# Out:
# 5

# %%
power(5, 9)
# Out:
# 1953125

# %%
#args allow us to pass a variable number of non - keyword arguments to a function. 

def multiply(*args): 
    product = 1
    for i in args: 
        product = product * i
    print(args)
    return product

# %%
multiply(5, 8, 99, 956)
# Out:
# (5, 8, 99, 956)
# 3785760

# %%
def calculate_profit(selling_price, cost_price): 
    profit = selling_price - cost_price
    return profit

sp = float(input("Enter selling price: "))
cp = float(input("Enter cost price: "))

profit = calculate_profit(sp, cp)

if profit > 0: 
    profit("profit:", profit)
elif profit < 0: 
    print("Loss:", abs(profit))
else: 
    profit("No profit no loss")
# Out:
# Enter selling price:  999
# Enter cost price:  2000
# Loss: 1001.0
