# %%
#Print
print("Hellow World")
# Out:
# Hellow World

# %%
#Variables
name = "Ujjawal Shrivastav"
age = 22
hight = "5.7ft"
is_student = "TRUE"

# %%
#Print variables 
print(name, age, hight)
# Out:
# Ujjawal Shrivastav 22 5.7ft

# %%
#Variable Data type
print(type(name))
print(type(age))
print(type(hight))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
#use Input
Name = input("Enter name: ")
college = input("Enter your college name: ")
course = input("Enter course name: ")

print("Name of student: ", Name)
print("college: ", college)
print("course: ", course)
# Out:
# Enter name:  Ujjawal Shrivastav
# Enter your college name:  MU
# Enter course name:  MBA'BA
# Name of student:  Ujjawal Shrivastav
# college:  MU
# course:  MBA'BA

# %%
#Task 
company = input("Enter company name: ")
salary = input("Enter your expected salary: ")

print("Company:", company)
print("Expected salary", salary)
# Out:
# Enter company name:  TCS
# Enter your expected salary:  7lpa
# Company: TCS
# Expected salary 7lpa
