# %%
#strings is text data 

name = "Ujjawal"

print(name[2]) #indexing
# Out:
# j

# %%
print(name[0:3]) #slicing
print(name[3:6])
# Out:
# Ujj
# awa

# %%
customer_name = input("Enter customer name: ")

clean_name = customer_name.strip().title()
print("Clean name:", clean_name)
# Out:
# Enter customer name:  Ujjawal shrivastav
# Clean name: Ujjawal Shrivastav

# %%
#file handling 
name = input("Enter employee name: ")
salary = input("Enter salary: ")

with open("Salary_report.txt", "w") as file: 
    file.write("Employee name: " + name + "\n")
    file.write("Salary: " + salary)
# Out:
# Enter employee name:  ujjawal
# Enter salary:  10000

# %%
#task 
name = input("Enter your name: ")#string

print("Upper: ", name.upper())
print("Lower: ", name.lower())
print("Title: ", name.title())

with open("user_dta.txt", "w") as file: 
    file.write("User Name: " + name)

print("Data saved to file successfully")
# Out:
# Enter your name:  Ujjawal Shrivastav
# Upper:  UJJAWAL SHRIVASTAV
# Lower:  ujjawal shrivastav
# Title:  Ujjawal Shrivastav
# Data saved to file successfully
